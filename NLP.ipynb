# %%
import pymorphy2
import nltk
import pandas as pd
import re
import string
from nltk.util import ngrams
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\xAniL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\xAniL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\xAniL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def read_text():
    with open("data.txt") as file:
        return file.read()
text = read_text()

# %%
tokens = nltk.word_tokenize(text)
tokens = [i for i in tokens if ( i not in string.punctuation )]
stop_words = stopwords.words('russian')
stop_words.extend(['лс','привет','ищу','ищем', 'это', 'я', 'hh', 'ru'])
tokens = [i for i in tokens if ( i not in stop_words )]
print(tokens)
# Out:
# ['вакансии', 'машинное', 'обучение', 'machine', 'learning', '1', '1', 'руководителя', 'группы', 'аналитиков', 'г', 'москва', 'необходим', 'опыт', 'прикладного', 'применения', 'методов', 'machine', 'learning', 'работы', 'различными', 'данными', '5', 'ти', 'лет', 'знание', 'методов', 'оценки', 'качества', 'аналитических', 'моделей', 'опыт', 'проектирования', 'batch', 'realtime', 'ml', 'систем', 'опыт', 'внедрения', 'ml', 'систем', 'инкрементального', 'улучшения', 'оценки', 'влияния', 'бизнес', 'метрики', 'дизайн', 'экспериментов', 'быстрой', 'проверки', 'продуктовых', 'гипотез', 'оценка', 'интерпретация', 'результатов', 'рассматриваем', 'кандидатов', 'любыми', 'пожеланиями', 'з', 'п', 'подробности', 'почту', '2', '2', 'агротерра', 'работодатель', '№1', 'агросекторе', 'связи', 'расширением', 'ищет', 'аналитика', 'старшего', 'аналитика', 'направления', 'углубленной', 'аналитики', 'data', 'scientist', 'московском', 'офисе', 'задачи', 'готовить', 'анализировать', 'данные', 'строить', 'внед
# ...

# %%
def LemTokens(tokens):
    lemmer = WordNetLemmatizer()
    return [lemmer.lemmatize(token) for token in tokens]

# %%
pymorph = pymorphy2.MorphAnalyzer()
for i,word in enumerate(tokens):
    word = pymorph.parse(word)[0].normal_form
    tokens[i] = word
#print(tokens)
words =ngrams(tokens,1)
bigrams=ngrams(tokens,2)
triplets =ngrams(tokens,3)

# %%
og = list(nltk.ngrams(tokens,1))
ogfd = nltk.FreqDist(og)
print(ogfd)
print(ogfd.most_common(10))
# Out:
# <FreqDist with 1481 samples and 3456 outcomes>
# [(('опыт',), 63), (('работа',), 54), (('дать',), 42), (('задача',), 38), (('компания',), 36), (('обучение',), 34), (('data',), 32), (('python',), 31), (('команда',), 29), (('знание',), 27)]

# %%
bg = list(nltk.bigrams(tokens))
bgfd = nltk.FreqDist(bg)
print(bgfd)
print(bgfd.most_common(10))
# Out:
# <FreqDist with 3132 samples and 3455 outcomes>
# [(('машинный', 'обучение'), 24), (('опыт', 'работа'), 23), (('big', 'data'), 9), (('machine', 'learning'), 8), (('data', 'science'), 7), (('опыт', 'разработка'), 7), (('компьютерный', 'зрение'), 7), (('английский', 'язык'), 7), (('алгоритм', 'машинный'), 6), (('нейронный', 'сеть'), 6)]

# %%
tg = list(nltk.ngrams(tokens,3))
tgfd = nltk.FreqDist(tg)
print(tgfd)
print(tgfd.most_common(10))
# Out:
# <FreqDist with 3412 samples and 3454 outcomes>
# [(('алгоритм', 'машинный', 'обучение'), 6), (('метод', 'машинный', 'обучение'), 3), (('зрение', 'машинный', 'обучение'), 3), (('команда', 'data', 'science'), 3), (('компьютерный', 'зрение', 'машинный'), 3), (('специалист', 'машинный', 'обучение'), 3), (('анализ', 'больший', 'дать'), 2), (('год', 'полный', 'занятость'), 2), (('язык', 'опыт', 'работа'), 2), (('junior', 'bi', 'разработчик'), 2)]
